# %% [markdown]
# # Big Data Analytics - Bash, Jupyter

# %% [markdown]
# # Bash and python

# %% [markdown]
# There are two ways we can interact with bash from within our jupyter notebook, first we can use magics.

# %% [markdown]
# Magics allow us to write different types of code, for example bash. Run the cell below to see a list of magics:

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# When we start a cell with %% the whole cell will be run as a magic. Note you cannot combine bash and python code in a single cell in this way. so for example we start a cell with %%bash to run only bash code in that cell:

# %%
# %%bash
# pwd
# Out:
# /Users/dhruvnovaims/Library/Mobile Documents/com~apple~CloudDocs/Documents/GitHub/bigDataLabsIMS25_26/weeks/week01/bash

# %%
import os
os.getcwd()
# Out:
# '/Users/dhruvnovaims/Library/Mobile Documents/com~apple~CloudDocs/Documents/GitHub/bigDataLabsIMS25_26/weeks/week01/bash'

# %%
# %%bash
# mkdir bashtest

# %%
# %%bash
# ls
# Out:
# bash_intro.md
# bashtest
# bdaBash.ipynb
# image-1.png
# image.png
# revision.md

# %%
# %%bash
# cd bashtest

# %%
# %%bash
# pwd
# Out:
# /Users/dhruvnovaims/Library/Mobile Documents/com~apple~CloudDocs/Documents/GitHub/bigDataLabsIMS25_26/weeks/week01/bash

# %% [markdown]
# We can also just use the ! at the start of bash a single bash line (again you cannot mix bash and python in a single cell):

# %%
# !ls
# Out:
# bash_intro.md bdaBash.ipynb image.png
# bashtest      image-1.png   revision.md

# %%
# %%bash
# curl -sS "https://en.wikipedia.org/wiki/List_of_European_Cup_and_UEFA_Champions_League_finals?action=raw"
# Out:
# {{Short description|None}}
# {{EngvarB|date=May 2020}}
# {{Use dmy dates|date=May 2020}}
#
# {{Infobox football tournament
# | image = Trofeo UEFA Champions League.jpg
# | imagesize = 150
# | caption = [[European Champion Clubs' Cup|European Cup&nbsp;/ Champions League trophy]]
# | founded = 1955
# | region = [[UEFA]] (Europe)
# | number of teams = 36 (league stage)<br>2 (finalists)
# | current champions = {{nowrap|{{fbaicon|FRA}} [[Paris Saint-Germain FC|Paris Saint-Germain]]<br />(1st title)}}
# | most successful club = {{fbaicon|ESP}} [[Real Madrid CF|Real Madrid]]<br>(15 titles)
# | current = [[2025 UEFA Champions League final]]
# }}
#
# The [[UEFA Champions League]] is a seasonal [[association football|football]] competition established in 1955.<ref name="History"/> Prior to the [[1992–93 UEFA Champions League|1992–93 season]], the tournament was named the European Cup.<ref name="History">{{cite web |title=Competition history |url=https://www.uefa.com/uefachampionsleague/history/ |publisher=UEFA |access-date=13 May 2020 |archive-date=22 November 2017 |archive-url=https://web.archive.org/web/20171122041336/http://www.uefa.com/uefachampionsleague/history/ |url-status=live }}</ref> The UEFA Champions League is open to the league champions of all [[UEFA]] (Union of European Football Associations) member associations (except [[Liechtenstein]], which has no league competition), as well as to the clubs finishing from second to fourth position in the strongest leagues.<ref>{{Cite web|date=30 July 2020|title=Access list|url=https://www.uefa.com/MultimediaFiles/Download/competitions/General/02/49/98/51/2499851_DOWNLOAD.pdf|publisher=UEFA|access-date=30 July 2020|archive-date=28 February 2018|archive-url=https://web.archive.org/web/20180228113434/http://www.uefa.com/MultimediaFiles/Download/competitions/General/02/49/98/51/2499851_DOWNLOAD.pdf|url-status=live}}</ref> Originally, only the champions of their respective national league and the defending champions of the competition were allowed to participate. However, this was changed in 1997 to allow the runners-up of the stronger leagues to compete as well, and again in 1999 when third and fourth-placed teams of the said leagues also became eligible.<ref>{{cite web |url=http://www.uefa.com/uefachampionsleague/history/season=1997/index.html |title=1997/98: Seventh heaven for Madrid |date=30 April 2010 |publisher=UEFA |access-date=8 July 2010 |archive-date=26 October 2012 |archive-url=https://web.archive.org/web/20121026011312/http://www.uefa.com/uefachampionsleague/history/season=1997/index.html |url-status=dead }}</ref> In the Champions League era, the defending champions of the competition did not automatically qualify until the rules were changed in 2005 to allow title holders [[Liverpool F.C.|Liverpool]] to enter the competition.<ref>{{cite news |title=Liverpool get in Champions League |url=http://news.bbc.co.uk/sport1/hi/football/teams/l/liverpool/4613695.stm |website=BBC Sport |date=10 June 2005 |access-date=8 July 2010 |archive-date=12 January 2016 |archive-url=https://web.archive.org/web/20160112095525/http://news.bbc.co.uk/sport1/hi/football/teams/l/liverpool/4613695.stm |url-status=live }}</ref>
#
# Teams that have won the UEFA Champions League three consecutive times, or five times overall, receive a [[European Champion Clubs' Cup#Multiple-winner badge|multiple-winner badge]].<ref>{{cite web |title=UEFA Champions League Museum |url=https://www.uefa.com/MultimediaFiles/Download/EuroExperience/competitions/UCL/01/95/53/46/1955346_DOWNLOAD.pdf |publisher=UEFA |access-date=22 June 2015 |page=10 |archive-date=6 November 2015 |archive-url=https://web.archive.org/web/20151106041024/http://www.uefa.com/MultimediaFiles/Download/EuroExperience/competitions/UCL/01/95/53/46/1955346_DOWNLOAD.pdf |url-status=dead }}</ref> Six teams have earned this privilege: [[Real Madrid CF|Real Madrid]], [[AFC Ajax|Ajax]], [[FC Bayern Munich|Bayern Munich]], [[AC Milan]], Liverpool, and [[FC Barcelona|Barcelona]].<ref>{{cite web|url=https://www.uefa.com/uefachampionsleague/news/0250-0c510c4a895e-12fa220d2fa3-1000--badge-of-honour-bestowed-on-barcelona/|title=Badge of honour bestowed on Barcelona|publisher=UEFA|access-date=8 May 2025|date=26 August 2015}}</ref><ref>{{cite web|url=https://www.uefa.com/uefachampionsleague/news/0250-0c511b10d395-72f38b4cbce0-1000--how-uefa-honours-multiple-european-cup-winners/|title=How UEFA honours multiple European Cup winners|publisher=UEFA|access-date=8 May 2025|date=21 May 2018}}</ref> Until 2009, clubs that had earned that badge were allowed to keep the [[European Champion Clubs' Cup]] and a new one was commissioned;<ref>{{cite web |title=Regulations of the UEFA Champions League 2007/08 |url=http://www.uefa.com/newsfiles/19071.pdf |publisher=UEFA |access-date=7 July 2010 |archive-url=https://web.archive.org/web/20070312003915/http://www.uefa.com/newsfiles/19071.pdf |archive-date=12 March 2007}}</ref> since 2009, the winning team each year has received a full-size replica of the trophy, while the original is retained by UEFA.<ref>{{cite web |title=Regulations of the UEFA Champions' League 2009/10 |url=https://www.uefa.com/MultimediaFiles/Download/Regulations/competitions/UCL/84/52/77/845277_DOWNLOAD.pdf |publisher=UEFA |access-date=20 October 2012 |archive-date=5 July 2016 |archive-url=https://web.archive.org/web/20160705204949/http://www.uefa.com/MultimediaFiles/Download/Regulations/competitions/UCL/84/52/77/845277_DOWNLOAD.pdf |url-status=live}}</ref>
#
# A total of 24 clubs have won the Champions League/European Cup. Real Madrid holds the record for the most victories, having won the competition 15 times, including the inaugural edition. They have also won the competition the most consecutive times, with five straight titles from 1956 to 1960. [[Juventus FC|Juventus]] have been runners-up the most times, losing seven finals. [[Atlético Madrid]] is the only team to reach three finals without having won the trophy while [[Stade de Reims|Reims]] and [[Valencia CF|Valencia]] have finished as runners-up twice without winning. Spain has provided the most champions, with twenty wins from two clubs.<ref name=uefa>{{cite web |first=Andrew |last=Haslam |title=Spain savour European pre-eminence |url=https://www.uefa.com/uefachampionsleague/news/01d9-0e723fb00248-203b61703893-1000--spain-savour-european-pre-eminence/ |publisher=UEFA |date=27 May 2009 |access-date=7 July 2010 |archive-date=4 June 2011 |archive-url=https://web.archive.org/web/20110604141148/http://www.uefa.com/uefachampionsleague/news/newsid=833250.html |url-status=live }}</ref> England have produced fifteen winners from a record six clubs and Italy have produced twelve winners from three clubs. English teams were banned from the competition for five years following the [[Heysel Stadium disaster|Heysel disaster]] in 1985.<ref>{{cite news |title=1985: English teams banned after Heysel |url=http://news.bbc.co.uk/onthisday/hi/dates/stories/may/31/newsid_2481000/2481723.stm |website=BBC News |date=31 May 1985 |access-date=8 August 2006 |archive-date=8 June 2017 |archive-url=https://web.archive.org/web/20170608132009/http://news.bbc.co.uk/onthisday/hi/dates/stories/may/31/newsid_2481000/2481723.stm |url-status=live }}</ref> The current champions are [[Paris Saint-Germain FC|Paris Saint-Germain]], who beat [[Inter Milan]] 5–0 in the [[2025 UEFA Champions League final|2025 final]].<ref>{{cite web |url=https://www.uefa.com/uefachampionsleague/news/0251-0e99b1ba85da-ec8053dc0a29-1000/ |title=Paris complete the 11th domestic league, domestic cup and European Cup/UEFA Champions League treble|publisher=UEFA|date=31 May 2025 |access-date=31 May 2025}}</ref>
#
# While the venue for the final is chosen well in advance, on four occasions clubs have reached a final scheduled to be played in their own stadium; Real Madrid won their second European Cup in the [[Santiago Bernabéu Stadium]] in 1957, while in 1965 Inter Milan also won their second title in the final at the [[San Siro]]. In 1984, the [[Stadio Olimpico]] in Rome was the venue and saw [[AS Roma|Roma]] defeated on penalties by Liverpool, while 2012 saw the [[Allianz Arena]] host the final between Bayern Munich and [[Chelsea F.C.|Chelsea]], which the English club also won on penalties.
#
# ==List of finals==
# ;Key
# {{legend|#FBCEB1|text={{dagger}}|Match was won during [[Overtime (sports)#Association football|extra time]]}}
# {{legend|#cedff2|text=<nowiki>*</nowiki>|Match was won on a [[Penalty shoot-out (association football)|penalty shoot-out]]}}
# {{legend|#d1f7a5|text=&|Match was won after a [[Replay (sports)#Association football|replay]]}}
#
# * The "Season" column refers to the season the competition was held, and [[H:WIKILINK|wikilink]]s to the article about that season.
# * The wikilinks in the "Score" column point to the article about that season's final game.
#
# {| class="wikitable plainrowheaders sortable"
# |+List of European Cup and UEFA Champions League finals<ref>{{Cite web |title=UEFA Champions League Finals 1956–2021 |url=https://www.rsssf.org/ec/ec1stats.html |url-status=live |archive-url=https://web.archive.org/web/20220812144813/https://www.rsssf.org/ec/ec1stats.html |archive-date=12 August 2022 |access-date=29 May 2022 |website=[[RSSSF]]}}</ref><ref>{{cite web |url=https://www.rsssf.org/tablese/ec1.html |title=European Champions' Cup |date=31 May 2012 |website=[[RSSSF]] |access-date=13 July 2012 |archive-date=6 July 2009 |archive-url=https://web.archive.org/web/20090706013641/http://www.rsssf.com/tablese/ec1.html |url-status=live }}</ref><ref>{{cite web |url=https://www.uefa.com/MultimediaFiles/Download/EuroExperience/competitions/Publications/02/28/56/89/2285689_DOWNLOAD.pdf |title=UEFA Champions League Statistics Handbook |publisher=UEFA |access-date=10 November 2022 |archive-date=12 June 2019 |archive-url=https://web.archive.org/web/20190612050823/https://www.uefa.com/MultimediaFiles/Download/EuroExperience/competitions/Publications/02/28/56/89/2285689_DOWNLOAD.pdf |url-status=dead }} See also {{cite web |url=https://editorial.uefa.com/resources/0282-18407a7a3056-fed61d05639b-1000/ucl_202223_finals_md13.pdf |title=2022–23 Season Update |archive-url=https://web.archive.org/web/20230821082639/https://editorial.uefa.com/resources/0282-18407a7a3056-fed61d05639b-1000/ucl_202223_finals_md13.pdf |archive-date=21 August 2023 |url-status=live }}</ref>
# |-
# !scope=col|Season
# !scope=col|Country
# !scope=col|Winners
# !scope=col|Score
# !scope=col|Runners-up
# !scope=col|Country
# !scope=col|Venue
# !scope="col"|Attend{{shy}}ance<ref>{{cite web |url=https://www.uefa.com/MultimediaFiles/Download/competitions/Statistics/01/85/99/80/1859980_DOWNLOAD.pdf |title=UEFA Champions League&nbsp;– Statistics Handbook 2012/13 |publisher=UEFA |page=141 |access-date=22 September 2013 |archive-date=25 February 2019 |archive-url=https://web.archive.org/web/20190225161925/https://www.uefa.com/MultimediaFiles/Download/competitions/Statistics/01/85/99/80/1859980_DOWNLOAD.pdf |url-status=live }}</ref>
# |-
# !scope="row" style="text-align:center"|[[1955–56 European Cup|1955–56]]
# |{{fba|ESP|1945|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center|[[1956 European Cup final|4–3]]
# |[[Stade de Reims|Reims]]
# |{{fba|FRA|1830|name=France}}
# |[[Parc des Princes]], Paris, France
# |align=center|38,239
# |-
# !scope="row" style="text-align:center"|[[1956–57 European Cup|1956–57]]
# |{{fba|ESP|1945|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center|[[1957 European Cup final|2–0]]
# |[[ACF Fiorentina|Fiorentina]]
# |{{fba|ITA|name=Italy}}
# |[[Santiago Bernabéu Stadium|Santiago Bernabéu]], Madrid, Spain
# |align=center|124,000
# |-
# !scope="row" style="text-align:center"|[[1957–58 European Cup|1957–58]]
# |{{fba|ESP|1945|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center bgcolor=FBCEB1|[[1958 European Cup final|3–2]]<sup>{{dagger}}</sup>
# |[[AC Milan|Milan]]
# |{{fba|ITA|name=Italy}}
# |[[King Baudouin Stadium|Heysel Stadium]], Brussels, Belgium
# |align=center|67,000
# |-
# !scope="row" style="text-align:center"|[[1958–59 European Cup|1958–59]]
# |{{fba|ESP|1945|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center|[[1959 European Cup final|2–0]]
# |[[Stade de Reims|Reims]]
# |{{fba|FRA|1830|name=France}}
# |[[MHPArena|Neckarstadion]], Stuttgart, West Germany
# |align=center|72,000
# |-
# !scope="row" style="text-align:center"|[[1959–60 European Cup|1959–60]]
# |{{fba|ESP|1945|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center|[[1960 European Cup final|7–3]]
# |[[Eintracht Frankfurt]]
# | data-sort-value="Germany" | {{fba|FRG|name=West Germany}}
# |[[Hampden Park]], Glasgow, Scotland
# |align=center|127,621
# |-
# !scope="row" style="text-align:center"|[[1960–61 European Cup|1960–61]]
# |{{fba|POR|name=Portugal}}
# |[[S.L. Benfica|Benfica]]
# |align=center|[[1961 European Cup final|3–2]]
# |[[FC Barcelona|Barcelona]]
# |{{fba|ESP|1945|name=Spain}}
# |[[Wankdorf Stadium]], Bern, Switzerland
# |align=center|26,732
# |-
# !scope="row" style="text-align:center"|[[1961–62 European Cup|1961–62]]
# |{{fba|POR|name=Portugal}}
# |[[S.L. Benfica|Benfica]]
# |align=center|[[1962 European Cup final|5–3]]
# |[[Real Madrid CF|Real Madrid]]
# |{{fba|ESP|1945|name=Spain}}
# |[[Olympic Stadium (Amsterdam)|Olympisch Stadion]], Amsterdam, Netherlands
# |align=center|61,257
# |-
# !scope="row" style="text-align:center"|[[1962–63 European Cup|1962–63]]
# |{{fba|ITA|name=Italy}}
# |[[AC Milan|Milan]]
# |align=center|[[1963 European Cup final|2–1]]
# |[[S.L. Benfica|Benfica]]
# |{{fba|POR|name=Portugal}}
# |[[Wembley Stadium (1923)|Wembley Stadium]], London, England
# |align=center|45,715
# |-
# !scope="row" style="text-align:center"|[[1963–64 European Cup|1963–64]]
# |{{fba|ITA|name=Italy}}
# |[[Inter Milan]]
# |align=center|[[1964 European Cup final|3–1]]
# |[[Real Madrid CF|Real Madrid]]
# |{{fba|ESP|1945|name=Spain}}
# |[[Ernst-Happel-Stadion|Praterstadion]], Vienna, Austria
# |align=center|71,333
# |-
# !scope="row" style="text-align:center"|[[1964–65 European Cup|1964–65]]
# |{{fba|ITA|name=Italy}}
# |[[Inter Milan]]
# |align=center|[[1965 European Cup final|1–0]]
# |[[S.L. Benfica|Benfica]]
# |{{fba|POR|name=Portugal}}
# |[[San Siro]], Milan, Italy
# |align=center|89,000
# |-
# !scope="row" style="text-align:center"|[[1965–66 European Cup|1965–66]]
# |{{fba|ESP|1945|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center|[[1966 European Cup final|2–1]]
# |[[FK Partizan|Partizan]]
# |{{fba|YUG|name=Yugoslavia}}
# |[[King Baudouin Stadium|Heysel Stadium]], Brussels, Belgium
# |align=center|46,745
# |-
# !scope="row" style="text-align:center"|[[1966–67 European Cup|1966–67]]
# |{{fba|SCO|name=Scotland}}
# |[[Celtic F.C.|Celtic]]
# |align=center|[[1967 European Cup final|2–1]]
# |[[Inter Milan]]
# |{{fba|ITA|name=Italy}}
# |[[Estádio Nacional]], Lisbon, Portugal
# |align=center|45,000
# |-
# !scope="row" style="text-align:center"|[[1967–68 European Cup|1967–68]]
# |{{fba|ENG|name=England}}
# |{{nowrap|[[Manchester United F.C.|Manchester United]]}}
# |align=center bgcolor=FBCEB1|[[1968 European Cup final|4–1]]<sup>{{dagger}}</sup>
# |[[S.L. Benfica|Benfica]]
# |{{fba|POR|name=Portugal}}
# |[[Wembley Stadium (1923)|Wembley Stadium]], London, England
# |align=center|92,225
# |-
# !scope="row" style="text-align:center"|[[1968–69 European Cup|1968–69]]
# |{{fba|ITA|name=Italy}}
# |[[AC Milan|Milan]]
# |align=center|[[1969 European Cup final|4–1]]
# |[[AFC Ajax|Ajax]]
# |{{fba|NED|name=Netherlands}}
# |[[Santiago Bernabéu Stadium|Santiago Bernabéu]], Madrid, Spain
# |align=center|31,782
# |-
# !scope="row" style="text-align:center"|[[1969–70 European Cup|1969–70]]
# |{{fba|NED|name=Netherlands}}
# |[[Feyenoord]]
# |align=center bgcolor=FBCEB1|[[1970 European Cup final|2–1]]<sup>{{dagger}}</sup>
# |[[Celtic F.C.|Celtic]]
# |{{fba|SCO|name=Scotland}}
# |[[San Siro]], Milan, Italy
# |align=center|53,187
# |-
# !scope="row" style="text-align:center"|[[1970–71 European Cup|1970–71]]
# |{{fba|NED|name=Netherlands}}
# |[[AFC Ajax|Ajax]]
# |align=center|[[1971 European Cup final|2–0]]
# |[[Panathinaikos F.C.|Panathinaikos]]
# |{{fba|GRE|1970|name=Greece}}
# |[[Wembley Stadium (1923)|Wembley Stadium]], London, England
# |align=center|83,179
# |-
# !scope="row" style="text-align:center"|[[1971–72 European Cup|1971–72]]
# |{{fba|NED|name=Netherlands}}
# |[[AFC Ajax|Ajax]]
# |align=center|[[1972 European Cup final|2–0]]
# |[[Inter Milan]]
# |{{fba|ITA|name=Italy}}
# |[[De Kuip]], Rotterdam, Netherlands
# |align=center|61,354
# |-
# !scope="row" style="text-align:center"|[[1972–73 European Cup|1972–73]]
# |{{fba|NED|name=Netherlands}}
# |[[AFC Ajax|Ajax]]
# |align=center|[[1973 European Cup final|1–0]]
# |[[Juventus FC|Juventus]]
# |{{fba|ITA|name=Italy}}
# |[[Red Star Stadium]], Belgrade, SFR Yugoslavia
# |align=center|89,484
# |-
# !scope="row" rowspan="2" style="text-align:center"|[[1973–74 European Cup|1973–74]]
# |rowspan="2" data-sort-value="Germany"|{{fba|FRG|name=West Germany}}
# |rowspan="2"|[[FC Bayern Munich|Bayern Munich]]
# |align=center|[[1974 European Cup final|1–1]]
# |rowspan="2"|[[Atlético Madrid]]
# |rowspan="2"|{{fba|ESP|1945|name=Spain}}
# |rowspan="2"|[[King Baudouin Stadium|Heysel Stadium]], Brussels, Belgium
# |align=center|48,722
# |-
# |align=center bgcolor=d1f7a5|[[1974 European Cup final|4–0]]<sup>&</sup>
# |align=center|23,325
# |-
# !scope="row" style="text-align:center"|[[1974–75 European Cup|1974–75]]
# |data-sort-value="Germany"|{{fba|FRG|name=West Germany}}
# |[[FC Bayern Munich|Bayern Munich]]
# |align=center|[[1975 European Cup final|2–0]]
# |[[Leeds United F.C.|Leeds United]]
# |{{fba|ENG|name=England}}
# |[[Parc des Princes]], Paris, France
# |align=center|48,374
# |-
# !scope="row" style="text-align:center"|[[1975–76 European Cup|1975–76]]
# | data-sort-value="Germany" | {{fba|FRG|name=West Germany}}
# |[[FC Bayern Munich|Bayern Munich]]
# |align=center|[[1976 European Cup final|1–0]]
# |[[AS Saint-Étienne|Saint-Étienne]]
# |{{fba|FRA|1974|name=France}}
# |[[Hampden Park]], Glasgow, Scotland
# |align=center|54,864
# |-
# !scope="row" style="text-align:center"|[[1976–77 European Cup|1976–77]]
# |{{fba|ENG|name=England}}
# |[[Liverpool F.C.|Liverpool]]
# |align=center|[[1977 European Cup final|3–1]]
# |[[Borussia Mönchengladbach]]
# | data-sort-value="Germany" | {{fba|FRG|name=West Germany}}
# |[[Stadio Olimpico]], Rome, Italy
# |align=center|57,000
# |-
# !scope="row" style="text-align:center"|[[1977–78 European Cup|1977–78]]
# |{{fba|ENG|name=England}}
# |[[Liverpool F.C.|Liverpool]]
# |align=center|[[1978 European Cup final|1–0]]
# |[[Club Brugge KV|Club Brugge]]
# |{{fba|BEL|name=Belgium}}
# |[[Wembley Stadium (1923)|Wembley Stadium]], London, England
# |align=center|92,500
# |-
# !scope="row" style="text-align:center"|[[1978–79 European Cup|1978–79]]
# |{{fba|ENG|name=England}}
# |[[Nottingham Forest F.C.|Nottingham Forest]]
# |align=center|[[1979 European Cup final|1–0]]
# |[[Malmö FF]]
# |{{fba|SWE|name=Sweden}}
# |[[Olympiastadion (Munich)|Olympiastadion]], Munich, West Germany
# |align=center|57,500
# |-
# !scope="row" style="text-align:center"|[[1979–80 European Cup|1979–80]]
# |{{fba|ENG|name=England}}
# |[[Nottingham Forest F.C.|Nottingham Forest]]
# |align=center|[[1980 European Cup final|1–0]]
# |[[Hamburger SV]]
# | data-sort-value="Germany" | {{fba|FRG|name=West Germany}}
# |[[Santiago Bernabéu Stadium|Santiago Bernabéu]], Madrid, Spain
# |align=center|51,000
# |-
# !scope="row" style="text-align:center"|[[1980–81 European Cup|1980–81]]
# |{{fba|ENG|name=England}}
# |[[Liverpool F.C.|Liverpool]]
# |align=center|[[1981 European Cup final|1–0]]
# |[[Real Madrid CF|Real Madrid]]
# |{{fba|ESP|1977|name=Spain}}
# | [[Parc des Princes]], Paris, France
# |align=center|48,360
# |-
# !scope="row" style="text-align:center"|[[1981–82 European Cup|1981–82]]
# |{{fba|ENG|name=England}}
# |[[Aston Villa F.C.|Aston Villa]]
# |align=center|[[1982 European Cup final|1–0]]
# |[[FC Bayern Munich|Bayern Munich]]
# | data-sort-value="Germany" | {{fba|FRG|name=West Germany}}
# |[[De Kuip]], Rotterdam, Netherlands
# |align=center|46,000
# |-
# !scope="row" style="text-align:center"|[[1982–83 European Cup|1982–83]]
# | data-sort-value="Germany" | {{fba|FRG|name=West Germany}}
# |[[Hamburger SV]]
# |align=center|[[1983 European Cup final|1–0]]
# |[[Juventus FC|Juventus]]
# |{{fba|ITA|name=Italy}}
# |[[Olympic Stadium (Athens)|Olympic Stadium]], Athens, Greece
# |align=center|73,500
# |-
# !scope="row" style="text-align:center"|[[1983–84 European Cup|1983–84]]
# |{{fba|ENG|name=England}}
# |[[Liverpool F.C.|Liverpool]]
# |align=center bgcolor=cedff2|[[1984 European Cup final|1–1]]*{{efn|Score was 1–1 after 90 minutes and extra time. Liverpool won the penalty shoot-out 4–2.<ref>{{cite web |url=http://www.uefa.com/uefachampionsleague/season=1983/index.html |title=1983/84: Kennedy spot on for Liverpool |publisher=UEFA |date=30 May 1984 |access-date=28 February 2012 |archive-date=13 July 2017 |archive-url=https://web.archive.org/web/20170713143316/http://www.uefa.com/uefachampionsleague/season=1983/index.html |url-status=dead }}</ref>}}
# |[[A.S. Roma|Roma]]
# |{{fba|ITA|name=Italy}}
# |[[Stadio Olimpico]], Rome, Italy
# |align=center|69,693
# |-
# !scope="row" style="text-align:center"|[[1984–85 European Cup|1984–85]]
# |{{fba|ITA|name=Italy}}
# |[[Juventus FC|Juventus]]
# |align=center|[[1985 European Cup final|1–0]]
# |[[Liverpool F.C.|Liverpool]]
# |{{fba|ENG|name=England}}
# |[[King Baudouin Stadium|Heysel Stadium]], Brussels, Belgium
# |align=center|58,000
# |-
# !scope="row" style="text-align:center"|[[1985–86 European Cup|1985–86]]
# |{{fba|ROU|1965|name=Romania}}
# |[[FCSB|Steaua București]]
# |align=center bgcolor=cedff2|[[1986 European Cup final|0–0]]*{{efn|Score was 0–0 after 90 minutes and extra time. Steaua București won the penalty shoot-out 2–0.<ref>{{cite web |url=https://www.uefa.com/uefachampionsleague/history/seasons/1985/ |title=Steaua stun Barcelona with spot-kick masterclass |publisher=UEFA|access-date=13 May 2020 |archive-date=28 May 2020 |archive-url=https://web.archive.org/web/20200528034227/https://www.uefa.com/uefachampionsleague/history/seasons/1985/ |url-status=live }}</ref>}}
# |[[FC Barcelona|Barcelona]]
# |{{fba|ESP|name=Spain}}
# |[[Ramón Sánchez Pizjuán Stadium|Ramón Sánchez Pizjuán]], Seville, Spain
# |align=center|70,000
# |-
# !scope="row" style="text-align:center"|[[1986–87 European Cup|1986–87]]
# |{{fba|POR|name=Portugal}}
# |[[FC Porto|Porto]]
# |align=center|[[1987 European Cup final|2–1]]
# |[[FC Bayern Munich|Bayern Munich]]
# | data-sort-value="Germany" | {{fba|FRG|name=West Germany}}
# |[[Ernst-Happel-Stadion|Praterstadion]], Vienna, Austria
# |align=center|57,500
# |-
# !scope="row" style="text-align:center"|[[1987–88 European Cup|1987–88]]
# |{{fba|NED|name=Netherlands}}
# |[[PSV Eindhoven]]
# |align=center bgcolor=cedff2|[[1988 European Cup final|0–0]]*{{efn|Score was 0–0 after 90 minutes and extra time. PSV Eindhoven won the penalty shoot-out 6–5.<ref>{{cite web |url=http://www.uefa.com/uefachampionsleague/season=1987/index.html |title=1987/88: PSV prosper from Oranje boom |publisher=UEFA |date=25 May 1988 |access-date=28 February 2012 |archive-date=21 February 2018 |archive-url=https://web.archive.org/web/20180221223901/http://www.uefa.com/uefachampionsleague/season=1987/index.html |url-status=dead }}</ref>}}
# |[[S.L. Benfica|Benfica]]
# |{{fba|POR|name=Portugal}}
# |[[MHPArena|Neckarstadion]], Stuttgart, West Germany
# |align=center|68,000
# |-
# !scope="row" style="text-align:center"|[[1988–89 European Cup|1988–89]]
# |{{fba|ITA|name=Italy}}
# |[[AC Milan|Milan]]
# |align=center|[[1989 European Cup final|4–0]]
# |[[FCSB|Steaua București]]
# |{{fba|ROU|1965|name=Romania}}
# |[[Camp Nou]], Barcelona, Spain
# |align=center|97,000
# |-
# !scope="row" style="text-align:center"|[[1989–90 European Cup|1989–90]]
# |{{fba|ITA|name=Italy}}
# |[[AC Milan|Milan]]
# |align=center|[[1990 European Cup final|1–0]]
# |[[S.L. Benfica|Benfica]]
# |{{fba|POR|name=Portugal}}
# |[[Ernst-Happel-Stadion|Praterstadion]], Vienna, Austria
# |align=center|57,558
# |-
# !scope="row" style="text-align:center"|[[1990–91 European Cup|1990–91]]
# |{{fba|YUG|name=Yugoslavia}}
# |[[Red Star Belgrade]]
# |align=center bgcolor=cedff2|[[1991 European Cup final|0–0]]*{{efn|Score was 0–0 after 90 minutes and extra time. Red Star Belgrade won the penalty shoot-out 5–3.<ref>{{cite web |url=http://www.uefa.com/uefachampionsleague/season=1990/index.html |title=1990/91: Crvena Zvezda spot on |publisher=UEFA |date=29 May 1991 |access-date=28 February 2012 |archive-date=13 March 2012 |archive-url=https://web.archive.org/web/20120313230122/http://www.uefa.com/uefachampionsleague/season=1990/index.html |url-status=dead }}</ref>}}
# |[[Olympique de Marseille|Marseille]]
# |{{fba|FRA|1974|name=France}}
# |[[Stadio San Nicola]], Bari, Italy
# |align=center|56,000
# |-
# !scope="row" style="text-align:center"|[[1991–92 European Cup|1991–92]]
# |{{fba|ESP|name=Spain}}
# |[[FC Barcelona|Barcelona]]
# |align=center bgcolor=FBCEB1|[[1992 European Cup final|1–0]]<sup>{{dagger}}</sup>
# |[[U.C. Sampdoria|Sampdoria]]
# |{{fba|ITA|name=Italy}}
# |[[Wembley Stadium (1923)|Wembley Stadium]], London, England
# |align=center|70,827
# |-
# !scope="row" style="text-align:center"|[[1992–93 UEFA Champions League|1992–93]]
# |{{fba|FRA|1974|name=France}}
# |[[Olympique de Marseille|Marseille]]
# |align=center|[[1993 UEFA Champions League final|1–0]]
# |[[AC Milan|Milan]]
# |{{fba|ITA|name=Italy}}
# |[[Olympiastadion (Munich)|Olympiastadion]], Munich, Germany
# |align=center|64,400
# |-
# !scope="row" style="text-align:center"|[[1993–94 UEFA Champions League|1993–94]]
# |{{fba|ITA|name=Italy}}
# |[[AC Milan|Milan]]
# |align=center|[[1994 UEFA Champions League final|4–0]]
# |[[FC Barcelona|Barcelona]]
# |{{fba|ESP|name=Spain}}
# |[[Olympic Stadium (Athens)|Olympic Stadium]], Athens, Greece
# |align=center|70,000
# |-
# !scope="row" style="text-align:center"|[[1994–95 UEFA Champions League|1994–95]]
# |{{fba|NED|name=Netherlands}}
# |[[AFC Ajax|Ajax]]
# |align=center|[[1995 UEFA Champions League final|1–0]]
# |[[AC Milan|Milan]]
# |{{fba|ITA|name=Italy}}
# |[[Ernst-Happel-Stadion]], Vienna, Austria
# |align=center|49,730
# |-
# !scope="row" style="text-align:center"|[[1995–96 UEFA Champions League|1995–96]]
# |{{fba|ITA|name=Italy}}
# |[[Juventus FC|Juventus]]
# |align=center bgcolor=cedff2|[[1996 UEFA Champions League final|1–1]]*{{efn|Score was 1–1 after 90 minutes and extra time. Juventus won the penalty shoot-out 4–2.<ref>{{cite web |url=http://www.uefa.com/uefachampionsleague/season=1995/index.html |title=1995/96: Juve hold their nerve |publisher=UEFA |date=22 May 1996 |access-date=28 February 2012 |archive-date=15 February 2012 |archive-url=https://web.archive.org/web/20120215215030/http://www.uefa.com/uefachampionsleague/season=1995/index.html |url-status=dead }}</ref>}}
# |[[AFC Ajax|Ajax]]
# |{{fba|NED|name=Netherlands}}
# |[[Stadio Olimpico]], Rome, Italy
# |align=center|70,000
# |-
# !scope="row" style="text-align:center"|[[1996–97 UEFA Champions League|1996–97]]
# |{{fba|GER|name=Germany}}
# |[[Borussia Dortmund]]
# |align=center|[[1997 UEFA Champions League final|3–1]]
# |[[Juventus FC|Juventus]]
# |{{fba|ITA|name=Italy}}
# |[[Olympiastadion (Munich)|Olympiastadion]], Munich, Germany
# |align=center|59,000
# |-
# !scope="row" style="text-align:center"|[[1997–98 UEFA Champions League|1997–98]]
# |{{fba|ESP|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center|[[1998 UEFA Champions League final|1–0]]
# |[[Juventus FC|Juventus]]
# |{{fba|ITA|name=Italy}}
# |[[Johan Cruyff Arena|Amsterdam Arena]], Amsterdam, Netherlands
# |align=center|48,500
# |-
# !scope="row" style="text-align:center"|[[1998–99 UEFA Champions League|1998–99]]
# |{{fba|ENG|name=England}}
# |[[Manchester United F.C.|Manchester United]]
# |align=center|[[1999 UEFA Champions League final|2–1]]
# |[[FC Bayern Munich|Bayern Munich]]
# |{{fba|GER|name=Germany}}
# |[[Camp Nou]], Barcelona, Spain
# |align=center|90,245
# |-
# !scope="row" style="text-align:center"|[[1999–2000 UEFA Champions League|1999–2000]]
# |{{fba|ESP|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center|[[2000 UEFA Champions League final|3–0]]
# |[[Valencia CF|Valencia]]
# |{{fba|ESP|name=Spain}}
# |[[Stade de France]], Saint-Denis, France
# |align=center|80,000
# |-
# !scope="row" style="text-align:center"|[[2000–01 UEFA Champions League|2000–01]]
# |{{fba|GER|name=Germany}}
# |[[FC Bayern Munich|Bayern Munich]]
# |align=center bgcolor=cedff2|[[2001 UEFA Champions League final|1–1]]*{{efn|Score was 1–1 after 90 minutes and extra time. Bayern Munich won the penalty shoot-out 5–4.<ref>{{cite web |url=http://www.uefa.com/uefachampionsleague/season=2000/index.html |title=2000/01: Kahn saves day for Bayern |publisher=UEFA |date=23 May 2001 |access-date=28 February 2012 |archive-date=27 March 2016 |archive-url=https://web.archive.org/web/20160327071541/http://www.uefa.com/uefachampionsleague/season=2000/index.html |url-status=dead }}</ref>}}
# |[[Valencia CF|Valencia]]
# |{{fba|ESP|name=Spain}}
# |[[San Siro]], Milan, Italy
# |align=center|79,000
# |-
# !scope="row" style="text-align:center"|[[2001–02 UEFA Champions League|2001–02]]
# |{{fba|ESP|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center|[[2002 UEFA Champions League final|2–1]]
# |[[Bayer 04 Leverkusen|Bayer Leverkusen]]
# |{{fba|GER|name=Germany}}
# |[[Hampden Park]], Glasgow, Scotland
# |align=center|50,499
# |-
# !scope="row" style="text-align:center"|[[2002–03 UEFA Champions League|2002–03]]
# |{{fba|ITA|2003|name=Italy}}
# |[[AC Milan|Milan]]
# |align=center bgcolor=cedff2|[[2003 UEFA Champions League final|0–0]]*{{efn|Score was 0–0 after 90 minutes and extra time. Milan won the penalty shoot-out 3–2.<ref>{{cite web |url=http://www.uefa.com/uefachampionsleague/season=2002/index.html |title=2002/03: Shevchenko spot on for Milan |publisher=UEFA |date=28 May 2003 |access-date=28 February 2012 |archive-date=18 February 2012 |archive-url=https://web.archive.org/web/20120218082852/http://www.uefa.com/uefachampionsleague/season=2002/index.html |url-status=dead }}</ref>}}
# |[[Juventus FC|Juventus]]
# |{{fba|ITA|2003|name=Italy}}
# |[[Old Trafford]], Manchester, England
# |align=center|62,315
# |-
# !scope="row" style="text-align:center"|[[2003–04 UEFA Champions League|2003–04]]
# |{{fba|POR|name=Portugal}}
# |[[FC Porto|Porto]]
# |align=center|[[2004 UEFA Champions League final|3–0]]
# |[[AS Monaco FC|Monaco]]
# |{{fba|FRA|1974|name=France}}
# |[[Arena AufSchalke]], Gelsenkirchen, Germany
# |align=center|53,053
# |-
# !scope="row" style="text-align:center"|[[2004–05 UEFA Champions League|2004–05]]
# |{{fba|ENG|name=England}}
# |[[Liverpool F.C.|Liverpool]]
# |align=center bgcolor=cedff2|[[2005 UEFA Champions League final|3–3]]*{{efn|Score was 3–3 after 90 minutes and extra time. Liverpool won the penalty shoot-out 3–2.<ref>{{cite web |url=http://www.uefa.com/uefachampionsleague/season=2004/index.html |title=2004/05: Liverpool belief defies Milan |publisher=UEFA |date=25 May 2005 |access-date=28 February 2012 |archive-date=18 February 2012 |archive-url=https://web.archive.org/web/20120218083301/http://www.uefa.com/uefachampionsleague/season=2004/index.html |url-status=dead }}</ref>}}
# |[[AC Milan|Milan]]
# |{{fba|ITA|2003|name=Italy}}
# |[[Atatürk Olympic Stadium]], Istanbul, Turkey
# |align=center|69,000
# |-
# !scope="row" style="text-align:center"|[[2005–06 UEFA Champions League|2005–06]]
# |{{fba|ESP|name=Spain}}
# |[[FC Barcelona|Barcelona]]
# |align=center|[[2006 UEFA Champions League final|2–1]]
# |[[Arsenal F.C.|Arsenal]]
# |{{fba|ENG|name=England}}
# |[[Stade de France]], Saint-Denis, France
# |align=center|79,610
# |-
# !scope="row" style="text-align:center"|[[2006–07 UEFA Champions League|2006–07]]
# |{{fba|ITA|name=Italy}}
# |[[AC Milan|Milan]]
# |align=center|[[2007 UEFA Champions League final|2–1]]
# |[[Liverpool F.C.|Liverpool]]
# |{{fba|ENG|name=England}}
# |[[Olympic Stadium (Athens)|Olympic Stadium]], Athens, Greece
# |align=center|63,000
# |-
# !scope="row" style="text-align:center"|[[2007–08 UEFA Champions League|2007–08]]
# |{{fba|ENG|name=England}}
# |[[Manchester United F.C.|Manchester United]]
# |align=center bgcolor=cedff2|[[2008 UEFA Champions League final|1–1]]*{{efn|Score was 1–1 after 90 minutes and extra time. Manchester United won the penalty shoot-out 6–5.<ref>{{cite web |url=http://www.uefa.com/uefachampionsleague/season=2008/index.html |title=2007/08: Fate favours triumphant United |publisher=UEFA |date=21 May 2008 |access-date=28 February 2012 |archive-date=18 February 2012 |archive-url=https://web.archive.org/web/20120218150212/http://www.uefa.com/uefachampionsleague/season=2008/index.html |url-status=dead }}</ref>}}
# |[[Chelsea F.C.|Chelsea]]
# |{{fba|ENG|name=England}}
# |[[Luzhniki Stadium]], Moscow, Russia
# |align=center|67,310
# |-
# !scope="row" style="text-align:center"|[[2008–09 UEFA Champions League|2008–09]]
# |{{fba|ESP|name=Spain}}
# |[[FC Barcelona|Barcelona]]
# |align=center|[[2009 UEFA Champions League final|2–0]]
# |[[Manchester United F.C.|Manchester United]]
# |{{fba|ENG|name=England}}
# |[[Stadio Olimpico]], Rome, Italy
# |align=center|62,467
# |-
# !scope="row" style="text-align:center"|[[2009–10 UEFA Champions League|2009–10]]
# |{{fba|ITA|name=Italy}}
# |[[Inter Milan]]
# |align=center|[[2010 UEFA Champions League final|2–0]]
# |[[FC Bayern Munich|Bayern Munich]]
# |{{fba|GER|name=Germany}}
# |[[Santiago Bernabéu Stadium|Santiago Bernabéu]], Madrid, Spain
# |align=center|73,490
# |-
# !scope="row" style="text-align:center"|[[2010–11 UEFA Champions League|2010–11]]
# |{{fba|ESP|name=Spain}}
# |[[FC Barcelona|Barcelona]]
# |align=center|[[2011 UEFA Champions League final|3–1]]
# |[[Manchester United F.C.|Manchester United]]
# |{{fba|ENG|name=England}}
# |[[Wembley Stadium]], London, England
# |align=center|87,695
# |-
# !scope="row" style="text-align:center"|[[2011–12 UEFA Champions League|2011–12]]
# |{{fba|ENG|name=England}}
# |[[Chelsea F.C.|Chelsea]]
# |align=center bgcolor=cedff2|[[2012 UEFA Champions League final|1–1]]*{{efn|Score was 1–1 after 90 minutes and extra time. Chelsea won the penalty shoot-out 4–3.<ref>{{cite web |url=https://www.uefa.com/uefachampionsleague/news/0250-0c50fb78a384-1434bbcadbcb-1000--shoot-out-win-ends-chelsea-s-long-wait-for-glory/ |title=Shoot-out win ends Chelsea's long wait for glory |publisher=UEFA |date=19 May 2012 |access-date=19 May 2012 |archive-date=22 May 2012 |archive-url=https://web.archive.org/web/20120522055119/http://www.uefa.com/uefachampionsleague/season=2012/matches/round=2000267/match=2007693/postmatch/report/index.html |url-status=live }}</ref>}}
# |[[FC Bayern Munich|Bayern Munich]]
# |{{fba|GER|name=Germany}}
# |[[Allianz Arena]], Munich, Germany
# |align=center|62,500
# |-
# !scope="row" style="text-align:center"|[[2012–13 UEFA Champions League|2012–13]]
# |{{fba|GER|name=Germany}}
# |[[FC Bayern Munich|Bayern Munich]]
# |align=center|[[2013 UEFA Champions League final|2–1]]
# |[[Borussia Dortmund]]
# |{{fba|GER|name=Germany}}
# |[[Wembley Stadium]], London, England
# |align=center|86,298
# |-
# !scope="row" style="text-align:center"|[[2013–14 UEFA Champions League|2013–14]]
# |{{fba|ESP|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center bgcolor=FBCEB1|[[2014 UEFA Champions League final|4–1]]<sup>{{dagger}}</sup>
# |[[Atlético Madrid]]
# |{{fba|ESP|name=Spain}}
# |[[Estádio da Luz]], Lisbon, Portugal
# |align=center|60,976
# |-
# !scope="row" style="text-align:center"|[[2014–15 UEFA Champions League|2014–15]]
# |{{fba|ESP|name=Spain}}
# |[[FC Barcelona|Barcelona]]
# |align=center|[[2015 UEFA Champions League final|3–1]]
# |[[Juventus FC|Juventus]]
# |{{fba|ITA|name=Italy}}
# |[[Olympiastadion (Berlin)|Olympiastadion]], Berlin, Germany
# |align=center|70,442
# |-
# !scope="row" style="text-align:center"|[[2015–16 UEFA Champions League|2015–16]]
# |{{fba|ESP|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center bgcolor=cedff2|[[2016 UEFA Champions League final|1–1]]*{{efn|Score was 1–1 after 90 minutes and extra time. Real Madrid won the penalty shoot-out 5–3.<ref>{{cite web |title=Spot-on Real Madrid defeat Atlético in final again |url=https://www.uefa.com/uefachampionsleague/news/022d-0e957c5979eb-37493cb53cd0-1000--spot-on-real-madrid-defeat-atletico-in-final-again/ |publisher=UEFA |date=28 May 2016 |access-date=29 May 2016 |archive-date=10 January 2018 |archive-url=https://web.archive.org/web/20180110225552/http://www.uefa.com/uefachampionsleague/season=2016/matches/round=2000638/match=2015789/postmatch/report/index.html |url-status=live }}</ref>}}
# |[[Atlético Madrid]]
# |{{fba|ESP|name=Spain}}
# |[[San Siro]], Milan, Italy
# |align=center|71,942
# |-
# !scope="row" style="text-align:center"|[[2016–17 UEFA Champions League|2016–17]]
# |{{fba|ESP|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center |[[2017 UEFA Champions League final|4–1]]
# |[[Juventus FC|Juventus]]
# |{{fba|ITA|name=Italy}}
# |[[Millennium Stadium]], Cardiff, Wales
# |align=center|65,842
# |-
# !scope="row" style="text-align:center"|[[2017–18 UEFA Champions League|2017–18]]
# |{{fba|ESP|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center |[[2018 UEFA Champions League final|3–1]]
# |[[Liverpool F.C.|Liverpool]]
# |{{fba|ENG|name=England}}
# |[[Olimpiyskiy National Sports Complex|NSC Olimpiyskiy Stadium]], Kyiv, Ukraine
# |align=center|61,561
# |-
# ! scope="row" style="text-align:center" |[[2018–19 UEFA Champions League|2018–19]]
# |{{fba|ENG|name=England}}
# |[[Liverpool F.C.|Liverpool]]
# | align="center" |[[2019 UEFA Champions League final|2–0]]
# |[[Tottenham Hotspur F.C.|Tottenham Hotspur]]
# |{{fba|ENG|name=England}}
# |[[Metropolitano Stadium]], Madrid, Spain
# | align="center" |63,272
# |-
# !scope="row" style="text-align:center"|[[2019–20 UEFA Champions League|2019–20]]
# |{{fba|GER|name=Germany}}
# |[[FC Bayern Munich|Bayern Munich]]
# |align=center |[[2020 UEFA Champions League final|1–0]]
# |[[Paris Saint-Germain FC|Paris Saint-Germain]]
# |{{fba|FRA|name=France}}
# |[[Estádio da Luz]], Lisbon, Portugal
# |align=center|0{{efn|The 2020 final was played behind closed doors due to the [[COVID-19 pandemic in Europe]].<ref name="behind closed doors">{{cite press release|url=https://www.uefa.com/news-media/news/025f-0fd8ee39d484-116d3b4051d6-1000/ |title=Venues for Round of 16 matches confirmed |publisher=UEFA|date=9 July 2020 |access-date=10 July 2020 |archive-date=9 August 2020 |archive-url=https://web.archive.org/web/20200809140337/https://www.uefa.com/insideuefa/mediaservices/mediareleases/news/025f-0fd8ee39d484-116d3b4051d6-1000/ |url-status=live }}</ref>}}
# |-
# !scope="row" style="text-align:center"|[[2020–21 UEFA Champions League|2020–21]]
# |{{fba|ENG|name=England}}
# |[[Chelsea F.C.|Chelsea]]
# |align=center |[[2021 UEFA Champions League final|1–0]]
# |[[Manchester City F.C.|Manchester City]]
# |{{fba|ENG|name=England}}
# |[[Estádio do Dragão]], Porto, Portugal
# | align="center" | 14,110{{Efn|The 2021 final was played with limited capacity due to the [[COVID-19 pandemic in Europe]].}}
# |-
# !scope="row" style="text-align:center"|[[2021–22 UEFA Champions League|2021–22]]
# |{{fba|ESP|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center |[[2022 UEFA Champions League final|1–0]]
# |[[Liverpool F.C.|Liverpool]]
# |{{fba|ENG|name=England}}
# |[[Stade de France]], Saint-Denis, France
# | align="center" | 75,000
# |-
# !scope="row" style="text-align:center"|[[2022–23 UEFA Champions League|2022–23]]
# |{{fba|ENG|name=England}}
# |[[Manchester City F.C.|Manchester City]]
# |align=center |[[2023 UEFA Champions League final|1–0]]
# |[[Inter Milan]]
# |{{fba|ITA|name=Italy}}
# |[[Atatürk Olympic Stadium]], Istanbul, Turkey
# | align="center" | 71,412
# |-
# !scope="row" style="text-align:center"|[[2023–24 UEFA Champions League|2023–24]]
# |{{fba|ESP|name=Spain}}
# |[[Real Madrid CF|Real Madrid]]
# |align=center |[[2024 UEFA Champions League final|2–0]]
# |[[Borussia Dortmund]]
# |{{fba|GER|name=Germany}}
# |[[Wembley Stadium]], London, England
# | align="center" | 86,212
# |-
# !scope="row" style="text-align:center"|[[2024–25 UEFA Champions League|2024–25]]
# |{{fba|FRA|name=France}}
# |{{nowrap|[[Paris Saint-Germain FC|Paris Saint-Germain]]}}
# |align=center |[[2025 UEFA Champions League final|5–0]]
# |[[Inter Milan]]
# |{{fba|ITA|name=Italy}}
# |[[Allianz Arena]], Munich, Germany
# | align="center" | 64,327
# |}
#
# {| class="wikitable plainrowheaders sortable"
# |+Upcoming finals
# |-
# !scope="col"|Season
# !scope="col"|Country
# !scope="col"|Finalist
# !scope="col"|Match
# !scope="col"|Finalist
# !scope="col"|Country
# !scope="col"|Venue
# |-
# !scope="row" style="text-align:center"|[[2025–26 UEFA Champions League|2025–26]]
# |
# |
# |align=center |[[2026 UEFA Champions League final|v]]
# |
# |
# |colspan="2"|[[Puskás Aréna]], Budapest, Hungary
# |-
# |}
#
# ==Performances==
# {{Further|European Cup and UEFA Champions League records and statistics#General performances}}
#
# ===By club===
# {{UEFA Champions League performance by club}}
#
# ===By nation===
# Clubs from thirteen nations have reached the final, and clubs from ten of those have won the competition. England has produced the most winning teams, with six clubs having won the trophy. Italy, Germany and the Netherlands have each had three clubs lift the title, while Spain, Portugal and France have had two winners apiece. Scotland, Romania and Yugoslavia have each had one club win the competition.
# <onlyinclude>
# {| class="wikitable plainrowheaders sortable" style="text-align:center"
# |+ Performances in finals by nation
# |-
# ! scope="col" | Nation
# ! scope="col" | Title(s)
# ! scope="col" | Runners-up
# ! scope="col" | Total
# |-
# ! scope="row" style="text-align:left" | {{fba|ESP}}
# | 20
# | 11
# | 31
# |-
# ! scope="row" style="text-align:left" | {{fba|ENG}}
# | 15
# | 11
# | 26
# |-
# ! scope="row" style="text-align:left" | {{fba|ITA}}
# | 12
# | 18
# | 30
# |-
# ! scope="row" style="text-align:left" | {{fba|GER}}{{efn|name="Germany"|Includes clubs representing [[West Germany]]. No clubs representing [[East Germany]] appeared in a final.}}
# | 8
# | 11
# | 19
# |-
# ! scope="row" style="text-align:left" | {{fba|NED}}
# | 6
# | 2
# | 8
# |-
# ! scope="row" style="text-align:left" | {{fba|POR}}
# | 4
# | 5
# | 9
# |-
# ! scope="row" style="text-align:left" | {{fba|FRA}}
# | 2
# | 6
# | 8
# |-
# ! scope="row" style="text-align:left" | {{fba|ROU}}
# | 1
# | 1
# | 2
# |-
# ! scope="row" style="text-align:left" | {{fba|SCO}}
# | 1
# | 1
# | 2
# |-
# ! scope="row" style="text-align:left" | {{fba|YUG}}{{efn|Both Yugoslav final appearances were by clubs from [[Socialist Republic of Serbia|SR Serbia]]}}
# | 1
# | 1
# | 2
# |-
# ! scope="row" style="text-align:left" | {{fba|BEL}}
# | 0
# | 1
# | 1
# |-
# ! scope="row" style="text-align:left" | {{fba|GRE}}
# | 0
# | 1
# | 1
# |-
# ! scope="row" style="text-align:left" | {{fba|SWE}}
# | 0
# | 1
# | 1
# |-
# |}</onlyinclude>
#
# {| class="wikitable sortable"
# |+ European Cup and UEFA Champions League winning clubs by nation
# ! Nation !! Winning clubs (in order of first win) !! Number of winners
# |-
# | {{fba|ENG|name=England}} || [[Manchester United F.C.|Manchester United]], [[Liverpool F.C.|Liverpool]], [[Nottingham Forest F.C.|Nottingham Forest]], [[Aston Villa F.C.|Aston Villa]], [[Chelsea F.C.|Chelsea]], [[Manchester City F.C.|Manchester City]] || 6
# |-
# | {{fba|ITA|name=Italy}} || [[AC Milan|Milan]], [[Inter Milan]], [[Juventus FC|Juventus]] || 3
# |-
# | {{fba|GER|name=Germany}} || [[FC Bayern Munich|Bayern Munich]], [[Hamburger SV]], [[Borussia Dortmund]] || 3
# |-
# | {{fba|NED|name=Netherlands}} || [[Feyenoord]], [[AFC Ajax|Ajax]], [[PSV Eindhoven]] || 3
# |-
# | {{fba|ESP|name=Spain}} || [[Real Madrid CF|Real Madrid]], [[FC Barcelona|Barcelona]] || 2
# |-
# | {{fba|POR|name=Portugal}} || [[S.L. Benfica|Benfica]], [[FC Porto|Porto]] || 2
# |-
# | {{fba|FRA|name=France}} || [[Olympique de Marseille|Marseille]], [[Paris Saint-Germain FC|Paris Saint-Germain]] || 2
# |-
# | {{fba|SCO|name=Scotland}} || [[Celtic F.C.|Celtic]] || 1
# |-
# | {{fba|ROU|name=Romania}} || [[FCSB|Steaua București]] || 1
# |-
# | {{fba|YUG|name=Yugoslavia}} || [[Red Star Belgrade]] || 1
# |}
#
# ==See also==
# *[[List of European Cup and UEFA Champions League winning managers]]
# *[[List of UEFA Cup and Europa League finals]]
# *[[List of UEFA Cup Winners' Cup finals]]
# *[[List of UEFA Super Cup matches]]
# *[[List of UEFA Conference League finals]]
# *[[List of UEFA Intertoto Cup winners]]
# *[[List of UEFA Women's Cup and Women's Champions League finals]]
#
# ==Notes==
# {{notelist}}
#
# ==References==
# {{Reflist}}
# {{commons category}}
#
# {{UEFA club competition winners}}
# {{UEFA Champions League winners}}
# {{UEFA Champions League final venues}}
# {{UEFA Champions League final referees}}
# {{UEFA Champions League seasons}}
# {{featured list}}
#
# [[Category:UEFA Champions League finals| ]]
# [[Category:UEFA Champions League]]
# [[Category:Lists of association football matches|European Cup and UEFA Champions League]]
