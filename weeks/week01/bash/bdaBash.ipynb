# %% [markdown]
# # Big Data Analytics - Bash, Jupyter

# %% [markdown]
# # Bash and python

# %% [markdown]
# There are two ways we can interact with bash from within our jupyter notebook, first we can use magics.

# %% [markdown]
# Magics allow us to write different types of code, for example bash. Run the cell below to see a list of magics:

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# When we start a cell with %% the whole cell will be run as a magic. Note you cannot combine bash and python code in a single cell in this way. so for example we start a cell with %%bash to run only bash code in that cell:

# %%
# %%bash
# pwd
# cd /home/jovyan/data
# pwd
# cd ..
# pwd
# Out:
# /content
# /content
# /
# bash: line 2: cd: /home/jovyan/data: No such file or directory

# %% [markdown]
# We can also just use the ! at the start of bash a single bash line (again you cannot mix bash and python in a single cell):

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# Check the directories below match where you placed your articles file and run the command:

# %%
# %%bash
# touch names.txt
# ls
# echo "Oliver" >> names.txt
# cat names.txt
# Out:
# rm: cannot remove 'Lines1.txt': No such file or directory
# rm: cannot remove 'Lines2.txt': No such file or directory
# bash: line 3: hdfs: command not found
# bash: line 4: hdfs: command not found

# %%
# %%bash
# rm names.txt

# %%
# %%bash
# curl -sS "https://en.wikipedia.org/wiki/List_of_European_Cup_and_UEFA_Champions_League_finals?action=raw"

# %%
# %%bash
# curl -sS "https://en.wikipedia.org/wiki/List_of_European_Cup_and_UEFA_Champions_League_finals?action=raw" \
# | grep -A1 -F '|{{fba' \
# | grep -v -F '{{fba' \
# | grep -oE '\[\[[^]]+\]\]' \
# | cut -d'|' -f2 \
# | cut -d']' -f1 \
# | sort -u
# Out:
# Ajax
# Amsterdam Arena
# Aston Villa
# Barcelona
# Bayern Munich
# Benfica
# Celtic
# Chelsea
# Heysel Stadium
# Juventus
# Liverpool
# Manchester City
# Manchester United
# Marseille
# Milan
# NSC Olimpiyskiy Stadium
# Neckarstadion
# Nottingham Forest
# Olympiastadion
# Olympic Stadium
# Olympisch Stadion
# Paris Saint-Germain
# Porto
# Praterstadion
# Ramón Sánchez Pizjuán
# Real Madrid
# Santiago Bernabéu
# Steaua București
# Wembley Stadium
# [[Allianz Arena
# [[Arena AufSchalke
# [[Atatürk Olympic Stadium
# [[Borussia Dortmund
# [[Camp Nou
# [[De Kuip
# [[Ernst-Happel-Stadion
# [[Estádio Nacional
# [[Estádio da Luz
# [[Estádio do Dragão
# [[Feyenoord
# [[Hampden Park
# [[Inter Milan
# [[Luzhniki Stadium
# [[Metropolitano Stadium
# [[Millennium Stadium
# [[Old Trafford
# [[PSV Eindhoven
# [[Parc des Princes
# [[Red Star Belgrade
# [[Red Star Stadium
# [[San Siro
# [[Stade de France
# [[Stadio Olimpico
# [[Stadio San Nicola
# [[Wankdorf Stadium
# [[Wembley Stadium
